# %%
import pandas as pd
import numpy as np

from mlxtend.frequent_patterns import apriori
from sklearn.preprocessing import KBinsDiscretizer
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('/Users/maria/Desktop/Code/HSE/MSZ/Данные_sem13.xlsx')

# %%
df
# Out:
#                           Регион  Естественный прирост  Безработица  \
# 0           Белгородская область                 -3649          3.6
# 1               Брянская область                 -1588          2.6
# 2           Владимирская область                 -3588          2.0
# 3            Воронежская область                  4392          3.2
# 4             Ивановская область                  -772          3.1
# ..                           ...                   ...          ...
# 77              Амурская область                 -2425          2.4
# 78           Магаданская область                  -412          3.4
# 79           Сахалинская область                 -1321          2.8
# 80  Еврейская автономная область                  -899          3.7
# 81    Чукотский автономный округ                   150          1.7
#
#     Средняя з/п  Температура  \
# 0       54495.1         9.15
# 1       48080.1         8.06
# 2       53285.6         6.38
# ...
