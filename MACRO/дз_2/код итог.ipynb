# %%
import pandas as pd
pd.set_option("display.max_columns", None)

import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df = pd.read_csv('/Users/maria/Desktop/Code/HSE/MACRO/дз_2/data - Лист1.csv')

# %%
df.shape
# Out:
# (34, 23)

# %%
new_values = [
    19.36, 17.08, 15.96, 17.20, 20.81, 19.31, 13.13, 18.11,
    28.85, 24.71, 25.12, 28.78, 38.23, 54.68, 65.60, 72.65, 97.33, 61.58,
    79.81, 111.54, 112.01, 108.96, 99.35, 53.02, 45.08, 54.89, 71.61, 64.20,
    43.33, 70.83, 98.99, 82.32, 79.91, 71.00
]

df["Oil Prices"] = new_values

# %%
df = df.drop(columns=["Import"])

# %%
df
# Out:
#     Year  Gross National Savings  Government Debt  Natural Gas Production  \
# 0   1992                36673.91            15.84                    5.75
# 1   1993                36673.91            15.84                    4.74
# 2   1994                36673.91            15.84                    3.18
# 3   1995                 3038.00            15.84                    4.19
# 4   1996                 4008.00            15.84                    4.63
# 5   1997                 3560.00            15.84                    5.75
# 6   1998                 3354.00            15.84                    5.63
# 7   1999                 2313.00            15.84                    7.15
# 8   2000                 3873.00            15.84                    8.18
# 9   2001                 5496.00            15.84                    8.23
# 10  2002                 7454.00            17.59                   10.00
# 11  2003                 8794.00            14.96                   11.77
# 12  2004                11831.00            11.39                   16.40
# 13  2005                16254.00             8.10                   18.98
# 14  2006                25163.00             6.68                   19.85
# 15  2007                30816.00            15.84                   22.51
# 16  2008                40147.00             6.77                   25.12
# 17  2009                33916.00            10.23                   26.01
# 18  2010                44991.00            10.68                   27.25
# 19  2011                63166.00            10.16                   28.67
# 20  2012                61890.00            12.13                   29.02
# 21  2013                68595.00            12.60                   30.45
# 22  2014                66738.00            14.50                   32.77
# 23  2015                50971.00            21.88                   27.14
# 24  2016                32811.00            19.68                   30.93
# 25  2017                43260.00            19.87                   36.38
# 26  2018                49841.00            20.26                   39.18
# 27  2019                48474.00            19.94                   33.50
# 28  2020                44876.00            26.36                   30.61
# 29  2021                48284.00            25.10                   26.70
# 30  2022                63778.00            23.52                   27.60
# 31  2023                70302.00            22.98                   30.82
# 32  2024                36673.91            24.80                   19.97
# 33  2025                36673.91            15.84                   19.97
#
#     Iron Ore Production  Inbound Foreign Direct Investment  \
# 0            17671000.0                             100.00
# 1            13128900.0                            1271.40
# 2            10520000.0                             659.70
# 3            14902200.0                             964.26
# 4            12975100.0                            1136.88
# 5            13132600.0                            1321.91
# 6             9335800.0                            1160.89
# 7             9616700.0                            1437.69
# 8            16156800.0                            1282.52
# 9            15886300.0                            2835.00
# 10           17675100.0                            2590.22
# 11           19364600.0                            2092.03
# 12           20302500.0                            4157.21
# 13           19471100.0                            1971.22
# 14           18254900.0                            6278.17
# 15           19582200.0                           11119.04
# 16           44847000.0                           14321.76
# 17           46248000.0                           13242.50
# 18           50190000.0                           11550.72
# 19           51742000.0                           13973.07
# 20           52614000.0                           13337.00
# 21           51758500.0                           10321.00
# 22           51540800.0                            8489.40
# 23           37269700.0                            4056.61
# 24           35793500.0                            8514.32
# 25           38728200.0                            4714.08
# 26           41876500.0                            3897.76
# 27           45221900.0                            3284.18
# 28           62865000.0                            3669.64
# 29           64089700.0                            3353.24
# 30           66000000.0                            6542.10
# 31           32363100.0                            3713.87
# 32           32363100.0                           -2550.49
# 33           32363100.0                            4994.21
#
#     Natural Population Growth  Government Budget Revenues  Coal Imports  \
# 0                   203480.54                    26573.71      70262.00
# 1                   203480.54                    26573.71      72918.00
# 2                   203480.54                     2637.00      80441.00
# 3                   203480.54                     2806.00      95686.00
# 4                   203480.54                     2781.00      42208.00
# 5                   203480.54                     2986.00      59005.00
# 6                   203480.54                     4026.00      90091.00
# 7                   203480.54                     2959.00     121177.00
# 8                    72276.00                     3998.00     228311.00
# 9                    73611.00                     5683.00     207326.00
# 10                   77790.00                     5531.00     196032.00
# 11                   92669.00                     7817.00     320938.00
# 12                  120778.00                    10594.00     379674.00
# 13                  121856.00                    16043.00     438410.00
# 14                  144546.00                    22237.00     299694.00
# 15                  163666.00                    30238.00     355638.00
# 16                  204677.00                    37757.00     292426.00
# 17                  213378.00                    25532.00     269045.00
# 18                  221680.00                    35447.00     124891.00
# 19                  228367.00                    52096.00      12708.00
# 20                  237742.00                    54793.00       8435.00
# 21                  250888.00                    58577.00       2829.00
# 22                  267022.00                    52569.00       2329.00
# 23                  267647.00                    30629.00       2126.00
# 24                  269463.00                    23348.00        355.00
# 25                  261253.00                    33064.00        123.00
# 26                  267351.00                    38425.00        321.00
# 27                  269182.00                    35750.00         98.00
# 28                  265491.00                    29955.00         21.00
# 29                  264088.00                    33714.00        193.00
# 30                  270370.00                    49210.00       3967.00
# 31                  257742.00                    57264.00      93445.00
# 32                  203480.54                    55319.00     120972.59
# 33                  203480.54                    26573.71     120972.59
#
#     Share of Military Expenditures in the Budget  Foreign Reserves  \
# 0                                           4.27          18604.72
# 1                                           4.27            711.00
# 2                                           4.27           1216.00
# 3                                           4.27           1660.00
# 4                                           4.27           1960.00
# 5                                           4.27           2223.00
# 6                                           4.27           1965.00
# 7                                           4.27           2001.00
# 8                                           4.27           2099.00
# 9                                           4.27           2506.00
# 10                                          4.86           3141.00
# 11                                          4.82           4962.00
# 12                                          4.65           9277.00
# 13                                          4.71           7070.00
# 14                                          4.94          19127.00
# 15                                          5.47          17641.00
# 16                                          4.27          19883.00
# 17                                          4.70          23183.00
# 18                                          4.51          28265.00
# 19                                          4.41          29215.00
# 20                                          4.78          28299.00
# 21                                          5.44          24692.00
# 22                                          4.90          29250.00
# 23                                          4.85          27855.00
# 24                                          4.34          29603.00
# 25                                          3.45          30747.00
# 26                                          4.43          30977.00
# 27                                          5.04          28958.00
# 28                                          3.70          35638.00
# 29                                          3.71          34378.00
# 30                                          2.38          35076.00
# 31                                          1.90          35965.00
# 32                                          1.94          45808.00
# 33                                          4.27          18604.72
#
#     GDP Growth  Average Annual Exchange Rate to USD  \
# 0        -5.30                               207.42
# 1        -9.20                               207.42
# 2       -12.60                                35.54
# 3        -8.20                                60.95
# 4         0.50                                67.30
# 5         1.70                                75.44
# 6        -1.90                                78.30
# 7         2.70                               119.52
# 8         9.80                               142.13
# 9        13.50                               146.74
# 10        9.80                               153.28
# 11        9.30                               149.58
# 12        9.60                               136.04
# 13        9.70                               132.88
# 14       10.70                               126.09
# 15        8.90                               122.55
# 16        3.30                               120.30
# 17        1.20                               147.50
# 18        7.30                               147.35
# 19        7.40                               146.62
# 20        4.80                               149.11
# 21        6.00                               152.13
# 22        4.20                               179.19
# 23        1.20                               221.73
# 24        1.10                               342.16
# 25        4.10                               326.00
# 26        4.10                               344.71
# 27        4.50                               382.75
# 28       -2.50                               412.95
# 29        4.30                               425.91
# 30        3.20                               460.16
# 31        5.10                               456.16
# 32        4.80                               468.96
# 33        3.43                               207.42
#
#     Fuel Exports, % of Merchandise Exports  Coal Exports  Electricity Exports  \
# 0                                    60.61   24994401.00                15.45
# 1                                    60.61   22651499.00                12.00
# 2                                    60.61   26181682.00                 5.50
# 3                                    24.99   20969975.00                 2.50
# 4                                    32.94   21071975.00                 1.73
# 5                                    34.16   25079970.00                 0.00
# 6                                    36.70   23402972.00                 0.13
# 7                                    43.64   17097980.00                 0.08
# 8                                    50.12   26238193.00                 0.08
# 9                                    56.07   29366459.00                 1.64
# 10                                   58.30   23110402.00                 2.00
# 11                                   61.22   27819719.00                 4.97
# 12                                   64.26   24395096.00                 7.40
# 13                                   70.12   24767594.00                 3.65
# 14                                   68.71   28700131.00                 3.73
# 15                                   66.01   25182518.00                 3.31
# 16                                   68.72   33947197.00                 2.48
# 17                                   69.51   25679366.00                 2.38
# 18                                   71.68   19166472.00                 1.76
# 19                                   72.02   19320647.00                 1.81
# 20                                   69.88   27531164.00                 2.93
# 21                                   76.30   33285368.00                 3.00
# 22                                   76.39   28485698.00                 2.92
# 23                                   67.72   27665236.00                 1.61
# 24                                   60.73   25158543.00                 2.57
# 25                                   63.33   26441609.00                 5.69
# 26                                   70.03   24846793.00                 5.04
# 27                                   66.24   24756726.00                 2.42
# 28                                   65.39   23833354.00                 2.32
# 29                                   65.61   22034118.00                 2.64
# 30                                   68.02   35948140.00                 2.24
# 31                                   58.93   34024881.00                 2.24
# 32                                   60.61   25723621.19                 3.38
# 33                                   60.61   25723621.19                 3.38
#
#     OIL Production  Oil Prices  Fiscal Rule  Expenditure  \
# 0           444.00       19.36          0.0        21.97
# 1           408.00       17.08          0.0        21.97
# 2           415.00       15.96          0.0        21.97
# 3           414.00       17.20          0.0        21.97
# 4           457.00       20.81          0.0        21.97
# 5           521.00       19.31          0.0        21.97
# 6           526.00       13.13          0.0        21.97
# 7           604.00       18.11          0.0        21.97
# 8           718.00       28.85          0.0        22.92
# 9           815.00       24.71          0.0        23.38
# 10          939.00       25.12          0.0        20.53
# 11         1027.00       28.78          0.0        21.36
# 12         1203.00       38.23          0.0        21.26
# 13         1288.00       54.68          0.0        22.01
# 14         1313.00       65.60          0.0        19.80
# 15         1360.00       72.65          0.0        23.71
# 16         1345.00       97.33          0.0        27.07
# 17         1455.00       61.58          0.0        23.47
# 18         1525.00       79.81          0.0        22.47
# 19         1553.00      111.54          0.0        21.23
# 20         1514.00      112.01          0.0        21.91
# 21         1573.00      108.96          0.0        19.81
# 22         1660.27       99.35          0.0        21.26
# 23         1623.29       53.02          0.0        22.87
# 24         1602.74       45.08          1.0        21.51
# 25         1771.23       54.89          1.0        24.09
# 26         1855.48       71.61          1.0        18.85
# 27         1857.53       64.20          1.0        20.25
# 28         1760.96       43.33          1.0        24.55
# 29         1760.62       70.83          1.0        22.07
# 30         1729.34       98.99          1.0        21.72
# 31         1848.76       82.32          1.0        23.39
# 32         1855.48       79.91          1.0        21.05
# 33         2019.86       71.00          1.0        18.65
#
#     Consumer Price Inflation  Politic leader
# 0                       8.66               0
# 1                       8.66               0
# 2                       8.66               0
# 3                       8.66               0
# 4                       8.66               0
# 5                       8.66               0
# 6                       8.66               0
# 7                       8.66               0
# 8                      13.15               0
# 9                       8.37               0
# 10                      5.85               0
# 11                      6.45               0
# 12                      6.87               0
# 13                      7.52               0
# 14                      8.58               0
# 15                     10.78               0
# 16                     17.15               0
# 17                      7.30               0
# 18                      7.13               0
# 19                      8.35               0
# 20                      5.11               0
# 21                      5.83               0
# 22                      6.72               0
# 23                      6.65               0
# 24                     14.56               0
# 25                      7.43               0
# 26                      6.02               0
# 27                      5.24               1
# 28                      6.80               1
# 29                      8.00               1
# 30                     14.96               1
# 31                     14.56               1
# 32                      8.64               1
# 33                      7.18               1

# %%
df.columns.tolist()
# Out:
# ['Year',
#  'Gross National Savings',
#  'Government Debt',
#  'Natural Gas Production',
#  'Iron Ore Production',
#  'Inbound Foreign Direct Investment',
#  'Natural Population Growth',
#  'Government Budget Revenues',
#  'Coal Imports',
#  'Share of Military Expenditures in the Budget',
#  'Foreign Reserves',
#  'GDP Growth',
#  'Average Annual Exchange Rate to USD',
#  'Fuel Exports, % of Merchandise Exports',
#  'Coal Exports',
#  'Electricity Exports',
#  'OIL Production',
#  'Oil Prices',
#  'Fiscal Rule',
#  'Expenditure',
#  'Consumer Price Inflation',
#  'Politic leader']

# %%
df.isna().mean() * 100
# Out:
# Year                                            0.0
# Gross National Savings                          0.0
# Government Debt                                 0.0
# Natural Gas Production                          0.0
# Iron Ore Production                             0.0
# Inbound Foreign Direct Investment               0.0
# Natural Population Growth                       0.0
# Government Budget Revenues                      0.0
# Coal Imports                                    0.0
# Share of Military Expenditures in the Budget    0.0
# Foreign Reserves                                0.0
# GDP Growth                                      0.0
# Average Annual Exchange Rate to USD             0.0
# Fuel Exports, % of Merchandise Exports          0.0
# Coal Exports                                    0.0
# Electricity Exports                             0.0
# OIL Production                                  0.0
# Oil Prices                                      0.0
# Fiscal Rule                                     0.0
# Expenditure                                     0.0
# Consumer Price Inflation                        0.0
# Politic leader                                  0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 22 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Year                                          34 non-null     int64
#  1   Gross National Savings                        34 non-null     float64
#  2   Government Debt                               34 non-null     float64
#  3   Natural Gas Production                        34 non-null     float64
#  4   Iron Ore Production                           34 non-null     float64
#  5   Inbound Foreign Direct Investment             34 non-null     float64
#  6   Natural Population Growth                     34 non-null     float64
#  7   Government Budget Revenues                    34 non-null     float64
#  8   Coal Imports                                  34 non-null     float64
#  9   Share of Military Expenditures in the Budget  34 non-null     float64
#  10  Foreign Reserves                              34 non-null     float64
#  11  GDP Growth                                    34 non-null     float64
#  12  Average Annual Exchange Rate to USD           34 non-null     float64
#  13  Fuel Exports, % of Merchandise Exports        34 non-null     float64
#  14  Coal Exports                                  34 non-null     float64
#  15  Electricity Exports                           34 non-null     float64
#  16  OIL Production                                34 non-null     float64
#  17  Oil Prices                                    34 non-null     float64
#  18  Fiscal Rule                                   34 non-null     float64
#  19  Expenditure                                   34 non-null     float64
#  20  Consumer Price Inflation                      34 non-null     float64
#  21  Politic leader                                34 non-null     int64
# dtypes: float64(20), int64(2)
# memory usage: 6.0 KB

# %%
df = df.rename(columns={"Year": "Date"})

# %% [markdown]
# ## 2. рост ВВП

# %% [markdown]
# ### 5. Выберите зависимую переменную для эконометрического исследования. Обоснуйте свой выбор. На отдельном графике представьте динамику выбранной переменной, опишите ее. Приведите ссылку на статистический источник.

# %%
df["GDP Growth"].describe().round(3)
# Out:
# count    34.000
# mean      3.427
# std       5.887
# min     -12.600
# 25%       1.200
# 50%       4.150
# 75%       7.375
# max      13.500
# Name: GDP Growth, dtype: float64

# %%
plt.figure()
plt.plot(df["Date"], df["GDP Growth"])
plt.xlabel("Year")
plt.ylabel("GDP Growth (% of GDP)")
plt.title("Dynamics of GDP Growth in Kazakhstan")
# Out:
# Text(0.5, 1.0, 'Dynamics of GDP Growth in Kazakhstan')

# %% [markdown]
# ### 6. Выберите объясняющую переменную, отвечающую за работу фискального правила. Обоснуйте свой выбор. На отдельном графике представьте динамику выбранной переменной, опишите ее. Приведите ссылку на статистический источник.

# %%
df["Oil Prices"].describe().round(3)
# Out:
# count     34.000
# mean      55.451
# std       31.757
# min       13.130
# 25%       24.812
# 50%       54.785
# 75%       78.020
# max      112.010
# Name: Oil Prices, dtype: float64

# %%
plt.figure()
plt.plot(df["Date"], df["Oil Prices"])
plt.xlabel("Year")
plt.ylabel("Oil Prices")
plt.title("Dynamics of Oil Prices in Kazakhstan")
# Out:
# Text(0.5, 1.0, 'Dynamics of Oil Prices in Kazakhstan')

# %% [markdown]
# ### 7. Выберите контрольные переменные для Вашего исследования. Обоснуйте свой выбор. На отдельном графике представьте динамику выбранных переменных, опишите ее. Приведите ссылки на статистические источники.

# %%
vars_to_plot = [
    'Oil Prices',                 # контрольная
    'Gross National Savings',
    'Government Debt',
    'Natural Gas Production',
    'Iron Ore Production',
    'Inbound Foreign Direct Investment',
    'Natural Population Growth',
    'Government Budget Revenues',
    'Coal Imports',
    'Share of Military Expenditures in the Budget',
    'Foreign Reserves',
    'Average Annual Exchange Rate to USD',
    'Fuel Exports, % of Merchandise Exports',
    'Coal Exports',
    'Electricity Exports',
    'OIL Production',
    'Fiscal Rule',
    'Expenditure',
    'Consumer Price Inflation',
    'Politic leader'
]

fig, axes = plt.subplots(11, 2, figsize=(12, 30))
axes = axes.flatten()

for i, var in enumerate(vars_to_plot):
    axes[i].plot(df["Date"], df[var])
    axes[i].set_title(var)
    axes[i].set_xlabel("Year")
    axes[i].set_ylabel(var)

plt.tight_layout()

# %% [markdown]
# ### 8. Если Вы используете дамми-переменную в своем исследовании, опишите и обоснуйте.

# %% [markdown]
# ### 9. Выпишите уравнение спецификации, которое Вы будете оценивать. В таблице опишите все основные описательные статистики выбранных переменных.

# %%
df.describe().round(2)
# Out:
#           Date  Gross National Savings  Government Debt  \
# count    34.00                   34.00            34.00
# mean   2008.50                33569.52            16.18
# std       9.96                22108.82             5.08
# min    1992.00                 2313.00             6.68
# 25%    2000.25                 9553.25            13.08
# 50%    2008.50                36673.91            15.84
# 75%    2016.75                48426.50            19.82
# max    2025.00                70302.00            26.36
#
#        Natural Gas Production  Iron Ore Production  \
# count                   34.00                34.00
# mean                    19.97          31936761.76
# std                     11.16          17705090.54
# min                      3.18           9335800.00
# 25%                      8.19          16535350.00
# 50%                     21.24          32363100.00
# 75%                     28.93          45991475.00
# max                     39.18          66000000.00
#
#        Inbound Foreign Direct Investment  Natural Population Growth  \
# count                              34.00                      34.00
# mean                             4994.21                  203480.54
# std                              4545.76                   61390.31
# min                             -2550.49                   72276.00
# 25%                              1350.86                  203480.54
# 50%                              3691.76                  203480.54
# 75%                              8002.58                  260375.25
# max                             14321.76                  270370.00
#
#        Government Budget Revenues  Coal Imports  \
# count                       34.00         34.00
# mean                     26573.71     120972.59
# std                      18631.01     129956.72
# min                       2637.00         21.00
# 25%                       6216.50       3113.50
# 50%                      26573.71      85266.00
# 75%                      37255.25     204502.50
# max                      58577.00     438410.00
#
#        Share of Military Expenditures in the Budget  Foreign Reserves  \
# count                                         34.00             34.00
# mean                                           4.27          18604.72
# std                                            0.82          13623.14
# min                                            1.90            711.00
# 25%                                            4.27           2664.75
# 50%                                            4.27          19505.00
# 75%                                            4.76          29241.25
# max                                            5.47          45808.00
#
#        GDP Growth  Average Annual Exchange Rate to USD  \
# count       34.00                                34.00
# mean         3.43                               207.42
# std          5.89                               128.28
# min        -12.60                                35.54
# 25%          1.20                               127.79
# 50%          4.15                               149.35
# 75%          7.38                               299.93
# max         13.50                               468.96
#
#        Fuel Exports, % of Merchandise Exports  Coal Exports  \
# count                                   34.00         34.00
# mean                                    60.61   25723621.19
# std                                     12.54    4220621.13
# min                                     24.99   17097980.00
# 25%                                     59.35   23510567.50
# 50%                                     63.80   25170530.50
# 75%                                     68.72   27631718.00
# max                                     76.39   35948140.00
#
#        Electricity Exports  OIL Production  Oil Prices  Fiscal Rule  \
# count                34.00           34.00       34.00        34.00
# mean                  3.38         1257.72       55.45         0.29
# std                   3.11          533.55       31.76         0.46
# min                   0.00          408.00       13.13         0.00
# 25%                   1.86          742.25       24.81         0.00
# 50%                   2.54         1407.50       54.78         0.00
# 75%                   3.58         1712.07       78.02         1.00
# max                  15.45         2019.86      112.01         1.00
#
#        Expenditure  Consumer Price Inflation  Politic leader
# count        34.00                     34.00           34.00
# mean         21.97                      8.66            0.21
# std           1.62                      2.93            0.41
# min          18.65                      5.11            0.00
# 25%          21.26                      6.82            0.00
# 50%          21.97                      8.36            0.00
# 75%          22.77                      8.66            0.00
# max          27.07                     17.15            1.00

# %% [markdown]
# ### 10.  Используя МНК, эмпирически оцените коэффициенты Вашей модели. Результаты оценки представьте в тексте в адекватном и аккуратном виде. Вы обязаны скопировать результаты из используемой программы в Приложение! Без этого работа оценивается как 0. Проинтерпретируйте полученные результаты.

# %% [markdown]
#  # Как варик брать не все-все переменные, а с самой большой корреляцыей по модулю

# %%
corr = df.corr(numeric_only=True)

plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %%
y = df["GDP Growth"]  # ВВП — зависимая

X = df[[
    
    "Gross National Savings",
    "Government Debt",
    "Natural Gas Production",
    "Iron Ore Production",
    "Inbound Foreign Direct Investment",
    "Natural Population Growth",
    "Government Budget Revenues",
    "Coal Imports",
    "Share of Military Expenditures in the Budget",
    "Foreign Reserves",
    "Average Annual Exchange Rate to USD",
    "Fuel Exports, % of Merchandise Exports",
    "Coal Exports",
    "Electricity Exports",
    "OIL Production",
    "Oil Prices",          # контрольная
    "Fiscal Rule",
    "Expenditure",
    "Consumer Price Inflation",
    "Politic leader"
]]

X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             GDP Growth   R-squared:                       0.921
# Model:                            OLS   Adj. R-squared:                  0.801
# Method:                 Least Squares   F-statistic:                     7.627
# Date:                Sun, 30 Nov 2025   Prob (F-statistic):           0.000267
# Time:                        13:30:45   Log-Likelihood:                -64.755
# No. Observations:                  34   AIC:                             171.5
# Df Residuals:                      13   BIC:                             203.6
# Df Model:                          20
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# const                                           14.0828     17.102      0.823      0.425     -22.864      51.030
# Gross National Savings                          -0.0004      0.000     -1.828      0.091      -0.001    6.51e-05
# Government Debt                                  0.1170      0.360      0.325      0.750      -0.661       0.895
# Natural Gas Production                           0.9006      0.461      1.954      0.073      -0.095       1.896
# Iron Ore Production                          -2.976e-07   1.18e-07     -2.519      0.026   -5.53e-07   -4.23e-08
# Inbound Foreign Direct Investment                0.0003      0.000      0.981      0.344      -0.000       0.001
# Natural Population Growth                    -7.402e-05   2.31e-05     -3.204      0.007      -0.000   -2.41e-05
# Government Budget Revenues                      -0.0003      0.000     -1.465      0.167      -0.001       0.000
# Coal Imports                                 -3.978e-05   1.53e-05     -2.595      0.022   -7.29e-05   -6.66e-06
# Share of Military Expenditures in the Budget    -2.0920      2.081     -1.005      0.333      -6.587       2.403
# Foreign Reserves                                -0.0001      0.000     -0.677      0.510      -0.000       0.000
# Average Annual Exchange Rate to USD              0.0370      0.032      1.143      0.274      -0.033       0.107
# Fuel Exports, % of Merchandise Exports           0.1287      0.187      0.690      0.502      -0.274       0.532
# Coal Exports                                  4.475e-08    1.6e-07      0.279      0.784   -3.02e-07    3.91e-07
# Electricity Exports                              0.5057      0.439      1.153      0.270      -0.442       1.454
# OIL Production                                   0.0012      0.006      0.193      0.850      -0.012       0.014
# Oil Prices                                       0.2754      0.114      2.409      0.032       0.028       0.522
# Fiscal Rule                                    -18.0652      6.394     -2.826      0.014     -31.878      -4.253
# Expenditure                                     -0.1749      0.635     -0.275      0.787      -1.547       1.198
# Consumer Price Inflation                         0.0057      0.418      0.014      0.989      -0.896       0.908
# Politic leader                                  10.0160      6.867      1.459      0.168      -4.819      24.851
# ==============================================================================
# Omnibus:                        2.556   Durbin-Watson:                   2.543
# Prob(Omnibus):                  0.279   Jarque-Bera (JB):                1.602
# Skew:                           0.279   Prob(JB):                        0.449
# Kurtosis:                       2.095   Cond. No.                     1.69e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.69e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model.params.round(5)
# Out:
# const                                           14.08282
# Gross National Savings                          -0.00036
# Government Debt                                  0.11700
# Natural Gas Production                           0.90058
# Iron Ore Production                             -0.00000
# Inbound Foreign Direct Investment                0.00033
# Natural Population Growth                       -0.00007
# Government Budget Revenues                      -0.00030
# Coal Imports                                    -0.00004
# Share of Military Expenditures in the Budget    -2.09200
# Foreign Reserves                                -0.00010
# Average Annual Exchange Rate to USD              0.03700
# Fuel Exports, % of Merchandise Exports           0.12868
# Coal Exports                                     0.00000
# Electricity Exports                              0.50575
# OIL Production                                   0.00117
# Oil Prices                                       0.27542
# Fiscal Rule                                    -18.06520
# Expenditure                                     -0.17486
# Consumer Price Inflation                         0.00572
# Politic leader                                  10.01595
# dtype: float64

# %%
p = model.pvalues

significant = [var for var in p.index if p[var] < 0.10]
nonsignificant = [var for var in p.index if p[var] >= 0.10]

print("Значимые переменные:", significant)
print("Незначимые переменные:", nonsignificant)
# Out:
# Значимые переменные: ['Gross National Savings', 'Natural Gas Production', 'Iron Ore Production', 'Natural Population Growth', 'Coal Imports', 'Oil Prices', 'Fiscal Rule']
# Незначимые переменные: ['const', 'Government Debt', 'Inbound Foreign Direct Investment', 'Government Budget Revenues', 'Share of Military Expenditures in the Budget', 'Foreign Reserves', 'Average Annual Exchange Rate to USD', 'Fuel Exports, % of Merchandise Exports', 'Coal Exports', 'Electricity Exports', 'OIL Production', 'Expenditure', 'Consumer Price Inflation', 'Politic leader']

# %% [markdown]
# также, построим 95% доверительные интервалы для всех коэффициентов:

# %%
conf = model.conf_int(alpha=0.05)

significant_ci = []
nonsignificant_ci = []

for var in conf.index:
    low, high = conf.loc[var]
    if low > 0 or high < 0:      # интервал не содержит ноль
        significant_ci.append(var)
    else:
        nonsignificant_ci.append(var)

print("Значимые по доверительным интервалам:", significant_ci)
print("Незначимые по доверительным интервалам:", nonsignificant_ci)
# Out:
# Значимые по доверительным интервалам: ['Iron Ore Production', 'Natural Population Growth', 'Coal Imports', 'Oil Prices', 'Fiscal Rule']
# Незначимые по доверительным интервалам: ['const', 'Gross National Savings', 'Government Debt', 'Natural Gas Production', 'Inbound Foreign Direct Investment', 'Government Budget Revenues', 'Share of Military Expenditures in the Budget', 'Foreign Reserves', 'Average Annual Exchange Rate to USD', 'Fuel Exports, % of Merchandise Exports', 'Coal Exports', 'Electricity Exports', 'OIL Production', 'Expenditure', 'Consumer Price Inflation', 'Politic leader']

# %% [markdown]
# ### 11.  Проведите проверку результатов на устойчивость. Метод Вы выбираете сами. Устойчивы ли Ваши результаты?

# %% [markdown]
# #### 1 способ: Робастные стандартные ошибки (HC3)

# %%
model_robust = model.get_robustcov_results(cov_type="HC3")

p = model_robust.pvalues
names = model_robust.model.exog_names

significant = [names[i] for i in range(len(p)) if p[i] < 0.10]
nonsignificant = [names[i] for i in range(len(p)) if p[i] >= 0.10]

print("Значимые (robust):", significant)
print("Незначимые (robust):", nonsignificant)
# Out:
# Значимые (robust): []
# Незначимые (robust): ['const', 'Gross National Savings', 'Government Debt', 'Natural Gas Production', 'Iron Ore Production', 'Inbound Foreign Direct Investment', 'Natural Population Growth', 'Government Budget Revenues', 'Coal Imports', 'Share of Military Expenditures in the Budget', 'Foreign Reserves', 'Average Annual Exchange Rate to USD', 'Fuel Exports, % of Merchandise Exports', 'Coal Exports', 'Electricity Exports', 'OIL Production', 'Oil Prices', 'Fiscal Rule', 'Expenditure', 'Consumer Price Inflation', 'Politic leader']

# %% [markdown]
# #### 2 способ: Мультиколлинеарность (VIF)

# %%
vif_data = pd.DataFrame()
vif_data["Variable"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif_data
# Out:
#                                         Variable          VIF
# 0                                          const  1439.603178
# 1                         Gross National Savings    89.310649
# 2                                Government Debt    16.010429
# 3                         Natural Gas Production   126.401095
# 4                            Iron Ore Production    20.898033
# 5              Inbound Foreign Direct Investment    10.835938
# 6                      Natural Population Growth     9.609125
# 7                     Government Budget Revenues    70.572332
# 8                                   Coal Imports    18.961685
# 9   Share of Military Expenditures in the Budget    13.821056
# 10                              Foreign Reserves    19.348399
# 11           Average Annual Exchange Rate to USD    82.441640
# 12        Fuel Exports, % of Merchandise Exports    26.157158
# 13                                  Coal Exports     2.186551
# 14                           Electricity Exports     8.922549
# 15                                OIL Production    50.423419
# 16                                    Oil Prices    62.960813
# 17                                   Fiscal Rule    41.770904
# 18                                   Expenditure     5.061338
# 19                      Consumer Price Inflation     7.125781
# 20                                Politic leader    37.946846

# %% [markdown]
# #### 3 способ: оценка модели на части признаков. (Leave-one-out robustness check)
#
# Мы проверяем, насколько чувствительны результаты модели к выбору набора регрессоров. Для этого по очереди исключаем из модели каждую объясняющую переменную, заново оцениваем регрессию и смотрим, как изменяется коэффициент при ключевой переменной FiscalRule. Если коэффициент остаётся примерно таким же, значит модель устойчива к спецификации; если изменяется резко, значит зависимость чувствительна к исключению этой переменной.
#
# Этот метод широко используется как тест устойчивости результатов (robustness to model specification).

# %%
y = df["GDP Growth"]

control_vars = [

    'Gross National Savings',
    'Government Debt',
    'Natural Gas Production',
    'Iron Ore Production',
    'Inbound Foreign Direct Investment',
    'Natural Population Growth',
    'Government Budget Revenues',
    'Coal Imports',
    'Share of Military Expenditures in the Budget',
    'Foreign Reserves',
    'Average Annual Exchange Rate to USD',
    'Fuel Exports, % of Merchandise Exports',
    'Coal Exports',
    'Electricity Exports',
    'OIL Production',
    'Expenditure',
    'Consumer Price Inflation',
    'Politic leader'
]

results = []

for var in control_vars:
    vars_subset = [v for v in control_vars if v != var]
    model = sm.OLS(y, sm.add_constant(df[vars_subset + ["Oil Prices"]])).fit()
    coef = model.params.get("Oil Prices", None)
    results.append([var, coef])

pd.DataFrame(results, columns=["Removed variable", "OilPrices coefficient"])
# Out:
#                                 Removed variable  OilPrices coefficient
# 0                         Gross National Savings               0.210763
# 1                                Government Debt               0.196444
# 2                         Natural Gas Production               0.213556
# 3                            Iron Ore Production               0.113140
# 4              Inbound Foreign Direct Investment               0.202370
# 5                      Natural Population Growth               0.307221
# 6                     Government Budget Revenues               0.135159
# 7                                   Coal Imports               0.188492
# 8   Share of Military Expenditures in the Budget               0.177961
# 9                               Foreign Reserves               0.202443
# 10           Average Annual Exchange Rate to USD               0.116529
# 11        Fuel Exports, % of Merchandise Exports               0.200393
# 12                                  Coal Exports               0.201933
# 13                           Electricity Exports               0.247586
# 14                                OIL Production               0.203833
# 15                                   Expenditure               0.158233
# 16                      Consumer Price Inflation               0.134532
# 17                                Politic leader               0.185354

# %% [markdown]
# ### 12.  Постройте прогноз, используя Вашу оцененную модель. Результаты представьте на графике. Опишите его и проинтерпретируйте.

# %% [markdown]
# прогноз по 3-летнему скользящему среднему (MA-3) и подстановка результата OLS-модель.

# %%
X_vars = [
   
    'Gross National Savings',
    'Government Debt',
    'Natural Gas Production',
    'Iron Ore Production',
    'Inbound Foreign Direct Investment',
    'Natural Population Growth',
    'Government Budget Revenues',
    'Coal Imports',
    'Share of Military Expenditures in the Budget',
    'Foreign Reserves',
    'Average Annual Exchange Rate to USD',
    'Fuel Exports, % of Merchandise Exports',
    'Coal Exports',
    'Electricity Exports',
    'OIL Production',
    'Oil Prices',          
    'Expenditure',
    'Consumer Price Inflation',
    'Politic leader',
    'Fiscal Rule'
]

future_years = [2026, 2027, 2028, 2029, 2030]

X_extended = df[X_vars].copy()

for year in future_years:
    ma3 = X_extended.tail(3).mean()
    X_extended.loc[year] = ma3

X_future = X_extended.loc[future_years].copy()
X_future["const"] = 1
X_future = X_future[model.model.exog_names]

forecast_ma = model.predict(X_future)

plt.figure(figsize=(10,5))
plt.plot(df["Date"], df["GDP Growth"], label="Факт")
plt.plot(forecast_ma.index, forecast_ma.values, label="Прогноз (MA3)", linestyle="--")
plt.xlabel("Год")
plt.ylabel("GDP Growth")
plt.legend()
plt.show()
