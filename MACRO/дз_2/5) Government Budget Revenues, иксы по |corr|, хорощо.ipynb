# 8         9.80                               142.13
# 9        13.50                               146.74
# 10        9.80                               153.28
# 11        9.30                               149.58
# 12        9.60                               136.04
# 13        9.70                               132.88
# 14       10.70                               126.09
# 15        8.90                               122.55
# 16        3.30                               120.30
# 17        1.20                               147.50
# 18        7.30                               147.35
# 19        7.40                               146.62
# 20        4.80                               149.11
# 21        6.00                               152.13
# 22        4.20                               179.19
# 23        1.20                               221.73
# 24        1.10                               342.16
# 25        4.10                               326.00
# 26        4.10                               344.71
# 27        4.50                               382.75
# 28       -2.50                               412.95
# 29        4.30                               425.91
# 30        3.20                               460.16
# 31        5.10                               456.16
# 32        4.80                               468.96
# 33        3.43                               207.42
#
#     Fuel Exports, % of Merchandise Exports  Coal Exports  Electricity Exports  \
# 0                                    60.61   24994401.00                15.45
# 1                                    60.61   22651499.00                12.00
# 2                                    60.61   26181682.00                 5.50
# 3                                    24.99   20969975.00                 2.50
# 4                                    32.94   21071975.00                 1.73
# 5                                    34.16   25079970.00                 0.00
# 6                                    36.70   23402972.00                 0.13
# 7                                    43.64   17097980.00                 0.08
# 8                                    50.12   26238193.00                 0.08
# 9                                    56.07   29366459.00                 1.64
# 10                                   58.30   23110402.00                 2.00
# 11                                   61.22   27819719.00                 4.97
# 12                                   64.26   24395096.00                 7.40
# 13                                   70.12   24767594.00                 3.65
# 14                                   68.71   28700131.00                 3.73
# 15                                   66.01   25182518.00                 3.31
# 16                                   68.72   33947197.00                 2.48
# 17                                   69.51   25679366.00                 2.38
# 18                                   71.68   19166472.00                 1.76
# 19                                   72.02   19320647.00                 1.81
# 20                                   69.88   27531164.00                 2.93
# 21                                   76.30   33285368.00                 3.00
# 22                                   76.39   28485698.00                 2.92
# 23                                   67.72   27665236.00                 1.61
# 24                                   60.73   25158543.00                 2.57
# 25                                   63.33   26441609.00                 5.69
# 26                                   70.03   24846793.00                 5.04
# 27                                   66.24   24756726.00                 2.42
# 28                                   65.39   23833354.00                 2.32
# 29                                   65.61   22034118.00                 2.64
# 30                                   68.02   35948140.00                 2.24
# 31                                   58.93   34024881.00                 2.24
# 32                                   60.61   25723621.19                 3.38
# 33                                   60.61   25723621.19                 3.38
#
#     OIL Production  Oil Prices  Fiscal Rule  Expenditure  \
# 0           444.00       66.89          0.0        21.97
# 1           408.00       66.89          0.0        21.97
# 2           415.00       66.89          0.0        21.97
# 3           414.00       66.89          0.0        21.97
# 4           457.00       66.89          0.0        21.97
# 5           521.00       66.89          0.0        21.97
# 6           526.00       66.89          0.0        21.97
# 7           604.00       66.89          0.0        21.97
# 8           718.00       29.36          0.0        22.92
# 9           815.00       24.46          0.0        23.38
# 10          939.00       24.99          0.0        20.53
# 11         1027.00       28.85          0.0        21.36
# 12         1203.00       38.26          0.0        21.26
# 13         1288.00       54.57          0.0        22.01
# 14         1313.00       65.16          0.0        19.80
# 15         1360.00       72.44          0.0        23.71
# 16         1345.00       96.94          0.0        27.07
# 17         1455.00       61.74          0.0        23.47
# 18         1525.00       79.61          0.0        22.47
# 19         1553.00      111.26          0.0        21.23
# 20         1514.00      111.57          0.0        21.91
# 21         1573.00      108.56          0.0        19.81
# 22         1660.27       98.97          0.0        21.26
# 23         1623.29       52.32          0.0        22.87
# 24         1602.74       43.64          1.0        21.51
# 25         1771.23       54.12          1.0        24.09
# 26         1855.48       71.34          1.0        18.85
# 27         1857.53       64.30          1.0        20.25
# 28         1760.96       41.96          1.0        24.55
# 29         1760.62       70.86          1.0        22.07
# 30         1729.34      100.93          1.0        21.72
# 31         1848.76       82.49          1.0        23.39
# 32         1855.48       80.52          1.0        21.05
# 33         2019.86       69.97          1.0        18.65
#
#     Consumer Price Inflation  Politic leader
# 0                       8.66               0
# 1                       8.66               0
# 2                       8.66               0
# 3                       8.66               0
# 4                       8.66               0
# 5                       8.66               0
# 6                       8.66               0
# 7                       8.66               0
# 8                      13.15               0
# 9                       8.37               0
# 10                      5.85               0
# 11                      6.45               0
# 12                      6.87               0
# 13                      7.52               0
# 14                      8.58               0
# 15                     10.78               0
# 16                     17.15               0
# 17                      7.30               0
# 18                      7.13               0
# 19                      8.35               0
# 20                      5.11               0
# 21                      5.83               0
# 22                      6.72               0
# 23                      6.65               0
# 24                     14.56               0
# 25                      7.43               0
# 26                      6.02               0
# 27                      5.24               1
# 28                      6.80               1
# 29                      8.00               1
# 30                     14.96               1
# 31                     14.56               1
# 32                      8.64               1
# 33                      7.18               1

# %%
df["Iron Ore Production"] = df["Iron Ore Production"].astype(float) / 1000
df["Coal Exports"] = df["Coal Exports"].astype(float) / 1000
df["Natural Population Growth"] = df["Natural Population Growth"].astype(float) / 1000

# %% [markdown]
# Iron Ore Production теперь в тыс.тонн

# %%
df["Natural Population Growth"] = df["Natural Population Growth"].astype(float) / 1000

# %% [markdown]
# Natural Population Growth- тыс.чел

# %%
df["Coal Exports"] = df["Coal Exports"].astype(float) / 1000

# %% [markdown]
# Coal Exports - тыс.тонн

# %%
df
# Out:
#     Year  Import  Gross National Savings  Government Debt  \
# 0   1992   75.33                36673.91            15.84
# 1   1993   46.74                36673.91            15.84
# 2   1994   47.12                36673.91            15.84
# 3   1995   43.55                 3038.00            15.84
# 4   1996   36.00                 4008.00            15.84
# 5   1997   37.44                 3560.00            15.84
# 6   1998   34.86                 3354.00            15.84
# 7   1999   40.12                 2313.00            15.84
# 8   2000   49.10                 3873.00            15.84
# 9   2001   46.95                 5496.00            15.84
# 10  2002   47.04                 7454.00            17.59
# 11  2003   43.05                 8794.00            14.96
# 12  2004   43.91                11831.00            11.39
# 13  2005   44.57                16254.00             8.10
# 14  2006   40.48                25163.00             6.68
# 15  2007   42.85                30816.00            15.84
# 16  2008   37.15                40147.00             6.77
# 17  2009   33.93                33916.00            10.23
# 18  2010   29.89                44991.00            10.68
# 19  2011   26.65                63166.00            10.16
# 20  2012   29.61                61890.00            12.13
# 21  2013   26.79                68595.00            12.60
# 22  2014   25.63                66738.00            14.50
# 23  2015   24.53                50971.00            21.88
# 24  2016   28.47                32811.00            19.68
# 25  2017   24.43                43260.00            19.87
# 26  2018   25.90                49841.00            20.26
# 27  2019   28.42                48474.00            19.94
# 28  2020   26.50                44876.00            26.36
# 23                    30629.00       2126.00
# 24                    23348.00        355.00
# 25                    33064.00        123.00
# 26                    38425.00        321.00
# 27                    35750.00         98.00
# 28                    29955.00         21.00
# 29                    33714.00        193.00
# 30                    49210.00       3967.00
# 31                    57264.00      93445.00
# 32                    55319.00     120972.59
# 33                    26573.71     120972.59
#
#     Share of Military Expenditures in the Budget  Foreign Reserves  \
# 0                                           4.27          18604.72
# 1                                           4.27            711.00
# 2                                           4.27           1216.00
# 3                                           4.27           1660.00
# 4                                           4.27           1960.00
# 5                                           4.27           2223.00
# 6                                           4.27           1965.00
# 7                                           4.27           2001.00
# 8                                           4.27           2099.00
# 9                                           4.27           2506.00
# 10                                          4.86           3141.00
# 11                                          4.82           4962.00
# 12                                          4.65           9277.00
# 13                                          4.71           7070.00
# 14                                          4.94          19127.00
# 15                                          5.47          17641.00
# 16                                          4.27          19883.00
# 17                                          4.70          23183.00
# 18                                          4.51          28265.00
# 19                                          4.41          29215.00
# 20                                          4.78          28299.00
# 21                                          5.44          24692.00
# 22                                          4.90          29250.00
# 23                                          4.85          27855.00
# 24                                          4.34          29603.00
# 25                                          3.45          30747.00
# 26                                          4.43          30977.00
# 27                                          5.04          28958.00
# 28                                          3.70          35638.00
# 29                                          3.71          34378.00
# 30                                          2.38          35076.00
# 31                                          1.90          35965.00
# 32                                          1.94          45808.00
# 33                                          4.27          18604.72
#
#     GDP Growth  Average Annual Exchange Rate to USD  \
# 0        -5.30                               207.42
# 1        -9.20                               207.42
# 2       -12.60                                35.54
# 3        -8.20                                60.95
# 4         0.50                                67.30
# 5         1.70                                75.44
# 6        -1.90                                78.30
# 7         2.70                               119.52
# 8         9.80                               142.13
# 9        13.50                               146.74
# 10        9.80                               153.28
# 11        9.30                               149.58
# 12        9.60                               136.04
# 13        9.70                               132.88
# 14       10.70                               126.09
# 15        8.90                               122.55
# 16        3.30                               120.30
# 17        1.20                               147.50
# 18        7.30                               147.35
# 19        7.40                               146.62
# 20        4.80                               149.11
# 21        6.00                               152.13
# 22        4.20                               179.19
# 23        1.20                               221.73
# 24        1.10                               342.16
# 25        4.10                               326.00
# 26        4.10                               344.71
# 27        4.50                               382.75
# 28       -2.50                               412.95
# 29        4.30                               425.91
# 30        3.20                               460.16
# 31        5.10                               456.16
# 32        4.80                               468.96
# 33        3.43                               207.42
#
#     Fuel Exports, % of Merchandise Exports  Coal Exports  Electricity Exports  \
# 0                                    60.61   24994.40100                15.45
# 1                                    60.61   22651.49900                12.00
# 2                                    60.61   26181.68200                 5.50
# 3                                    24.99   20969.97500                 2.50
# 4                                    32.94   21071.97500                 1.73
# 5                                    34.16   25079.97000                 0.00
# 6                                    36.70   23402.97200                 0.13
# 7                                    43.64   17097.98000                 0.08
# 8                                    50.12   26238.19300                 0.08
# 9                                    56.07   29366.45900                 1.64
# 10                                   58.30   23110.40200                 2.00
# 11                                   61.22   27819.71900                 4.97
# 12                                   64.26   24395.09600                 7.40
# 13                                   70.12   24767.59400                 3.65
# 14                                   68.71   28700.13100                 3.73
# 15                                   66.01   25182.51800                 3.31
#  'Government Debt',
#  'Natural Gas Production',
#  'Iron Ore Production',
#  'Inbound Foreign Direct Investment',
#  'Natural Population Growth',
#  'Government Budget Revenues',
#  'Coal Imports',
#  'Share of Military Expenditures in the Budget',
#  'Foreign Reserves',
#  'GDP Growth',
#  'Average Annual Exchange Rate to USD',
#  'Fuel Exports, % of Merchandise Exports',
#  'Coal Exports',
#  'Electricity Exports',
#  'OIL Production',
#  'Oil Prices',
#  'Fiscal Rule',
#  'Expenditure',
#  'Consumer Price Inflation',
#  'Politic leader']

# %%
df.isna().mean() * 100
# Out:
# Year                                            0.0
# Import                                          0.0
# Gross National Savings                          0.0
# Government Debt                                 0.0
# Natural Gas Production                          0.0
# Iron Ore Production                             0.0
# Inbound Foreign Direct Investment               0.0
# Natural Population Growth                       0.0
# Government Budget Revenues                      0.0
# Coal Imports                                    0.0
# Share of Military Expenditures in the Budget    0.0
# Foreign Reserves                                0.0
# GDP Growth                                      0.0
# Average Annual Exchange Rate to USD             0.0
# Fuel Exports, % of Merchandise Exports          0.0
# Coal Exports                                    0.0
# Electricity Exports                             0.0
# OIL Production                                  0.0
# Oil Prices                                      0.0
# Fiscal Rule                                     0.0
# Expenditure                                     0.0
# Consumer Price Inflation                        0.0
# Politic leader                                  0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 23 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Year                                          34 non-null     int64
#  1   Import                                        34 non-null     float64
#  2   Gross National Savings                        34 non-null     float64
#  3   Government Debt                               34 non-null     float64
#  4   Natural Gas Production                        34 non-null     float64
#  5   Iron Ore Production                           34 non-null     float64
#  6   Inbound Foreign Direct Investment             34 non-null     float64
#  7   Natural Population Growth                     34 non-null     float64
#  8   Government Budget Revenues                    34 non-null     float64
#  9   Coal Imports                                  34 non-null     float64
#  10  Share of Military Expenditures in the Budget  34 non-null     float64
#  11  Foreign Reserves                              34 non-null     float64
#  12  GDP Growth                                    34 non-null     float64
#  13  Average Annual Exchange Rate to USD           34 non-null     float64
#  14  Fuel Exports, % of Merchandise Exports        34 non-null     float64
#  15  Coal Exports                                  34 non-null     float64
#  16  Electricity Exports                           34 non-null     float64
#  17  OIL Production                                34 non-null     float64
#  18  Oil Prices                                    34 non-null     float64
#  19  Fiscal Rule                                   34 non-null     float64
#  20  Expenditure                                   34 non-null     float64
#  21  Consumer Price Inflation                      34 non-null     float64
#  22  Politic leader                                34 non-null     int64
# dtypes: float64(21), int64(2)
# memory usage: 6.2 KB

# %%
df = df.rename(columns={"Year": "Date"})

# %% [markdown]
# ## 5. Government Budget Revenues

# %% [markdown]
# ### 5. Выберите зависимую переменную для эконометрического исследования. Обоснуйте свой выбор. На отдельном графике представьте динамику выбранной переменной, опишите ее. Приведите ссылку на статистический источник.

# %%
df["Government Budget Revenues"].describe().round(3)
# Out:
# count       34.000
# mean     26573.710
# std      18631.007
# min       2637.000
# 25%       6216.500
# 50%      26573.710
# 75%      37255.250
# max      58577.000
# Name: Government Budget Revenues, dtype: float64

# %%
plt.figure()
plt.plot(df["Date"], df["Government Budget Revenues"])
plt.xlabel("Year")
plt.ylabel("Government Budget Revenues (% of GDP)")
plt.title("Dynamics of Government Budget Revenues in Kazakhstan")
# Out:
# Text(0.5, 1.0, 'Dynamics of Government Budget Revenues in Kazakhstan')

# %% [markdown]
# ### 6. Выберите объясняющую переменную, отвечающую за работу фискального правила. Обоснуйте свой выбор. На отдельном графике представьте динамику выбранной переменной, опишите ее. Приведите ссылку на статистический источник.

# %%
df["Oil Prices"].describe().round(3)
# Out:
# count     34.000
# mean      66.891
# std       23.623
# min       24.460
# 25%       54.232
# 50%       66.890
# 75%       77.818
# max      111.570
# Name: Oil Prices, dtype: float64

# %%
plt.figure()
plt.plot(df["Date"], df["Oil Prices"])
plt.xlabel("Year")
plt.ylabel("Oil Prices")
plt.title("Dynamics of Oil Prices in Kazakhstan")
# Out:
# Text(0.5, 1.0, 'Dynamics of Oil Prices in Kazakhstan')

# %% [markdown]
# ### 7. Выберите контрольные переменные для Вашего исследования. Обоснуйте свой выбор. На отдельном графике представьте динамику выбранных переменных, опишите ее. Приведите ссылки на статистические источники.

# %%
y = df["Government Budget Revenues"]   # новая целевая

vars_to_plot = [
    'Oil Prices',                 
    'Import',
    'Gross National Savings',
    'Natural Gas Production',
    'Iron Ore Production',
    'Inbound Foreign Direct Investment',
    'Natural Population Growth',
    'Coal Imports',
    'Share of Military Expenditures in the Budget',
    'Foreign Reserves',
    'GDP Growth',
    'Average Annual Exchange Rate to USD',
    'Fuel Exports, % of Merchandise Exports',
    'Coal Exports',
    'Electricity Exports',
    'OIL Production',
    'Fiscal Rule',
    'Expenditure',
    'Consumer Price Inflation',
    'Politic leader'
]

fig, axes = plt.subplots(11, 2, figsize=(12, 30))
axes = axes.flatten()

for i, var in enumerate(vars_to_plot):
    axes[i].plot(df["Date"], df[var])
    axes[i].set_title(var)
    axes[i].set_xlabel("Year")
    axes[i].set_ylabel(var)

plt.tight_layout()

# %% [markdown]
# ### 8. Если Вы используете дамми-переменную в своем исследовании, опишите и обоснуйте.

# %% [markdown]
# ### 9. Выпишите уравнение спецификации, которое Вы будете оценивать. В таблице опишите все основные описательные статистики выбранных переменных.

# %%
df.describe().round(2)
# Out:
#           Date  Import  Gross National Savings  Government Debt  \
# count    34.00   34.00                   34.00            34.00
# mean   2008.50   36.53                33569.52            16.18
# std       9.96   10.65                22108.82             5.08
# min    1992.00   24.43                 2313.00             6.68
# 25%    2000.25   26.96                 9553.25            13.08
# 50%    2008.50   36.58                36673.91            15.84
# 75%    2016.75   43.42                48426.50            19.82
# max    2025.00   75.33                70302.00            26.36
#
#        Natural Gas Production  Iron Ore Production  \
# count                   34.00                34.00
# mean                    19.97             31936.76
# std                     11.16             17705.09
# min                      3.18              9335.80
# 25%                      8.19             16535.35
# 50%                     21.24             32363.10
# 75%                     28.93             45991.48
# max                     39.18             66000.00
#
#        Inbound Foreign Direct Investment  Natural Population Growth  \
# count                              34.00                      34.00
# mean                             4994.21                     203.48
# std                              4545.76                      61.39
# min                             -2550.49                      72.28
# 25%                              1350.86                     203.48
# 50%                              3691.76                     203.48
# 75%                              8002.58                     260.38
# max                             14321.76                     270.37
#
#        Government Budget Revenues  Coal Imports  \
# count                       34.00         34.00
# mean                     26573.71     120972.59
# std                      18631.01     129956.72
# min                       2637.00         21.00
# 25%                       6216.50       3113.50
# 50%                      26573.71      85266.00
# 75%                      37255.25     204502.50
# max                      58577.00     438410.00
#
#        Share of Military Expenditures in the Budget  Foreign Reserves  \
# count                                         34.00             34.00
# mean                                           4.27          18604.72
# std                                            0.82          13623.14
# min                                            1.90            711.00
# 25%                                            4.27           2664.75
# 50%                                            4.27          19505.00
# 75%                                            4.76          29241.25
# max                                            5.47          45808.00
#
#        GDP Growth  Average Annual Exchange Rate to USD  \
# count       34.00                                34.00
# mean         3.43                               207.42
# std          5.89                               128.28
# min        -12.60                                35.54
# 25%          1.20                               127.79
# 50%          4.15                               149.35
# 75%          7.38                               299.93
# max         13.50                               468.96
#
#        Fuel Exports, % of Merchandise Exports  Coal Exports  \
# count                                   34.00         34.00
# mean                                    60.61      25723.62
# std                                     12.54       4220.62
# min                                     24.99      17097.98
# 25%                                     59.35      23510.57
# 50%                                     63.80      25170.53
# 75%                                     68.72      27631.72
# max                                     76.39      35948.14
#
#        Electricity Exports  OIL Production  Oil Prices  Fiscal Rule  \
# count                34.00           34.00       34.00        34.00
# mean                  3.38         1257.72       66.89         0.29
# std                   3.11          533.55       23.62         0.46
# min                   0.00          408.00       24.46         0.00
# 25%                   1.86          742.25       54.23         0.00
# 50%                   2.54         1407.50       66.89         0.00
# 75%                   3.58         1712.07       77.82         1.00
# max                  15.45         2019.86      111.57         1.00
#
#        Expenditure  Consumer Price Inflation  Politic leader
# count        34.00                     34.00           34.00
# mean         21.97                      8.66            0.21
# std           1.62                      2.93            0.41
# min          18.65                      5.11            0.00
# 25%          21.26                      6.82            0.00
# 50%          21.97                      8.36            0.00
# 75%          22.77                      8.66            0.00
# max          27.07                     17.15            1.00

# %% [markdown]
# ### 10.  Используя МНК, эмпирически оцените коэффициенты Вашей модели. Результаты оценки представьте в тексте в адекватном и аккуратном виде. Вы обязаны скопировать результаты из используемой программы в Приложение! Без этого работа оценивается как 0. Проинтерпретируйте полученные результаты.

# %% [markdown]
#  # Как варик брать не все-все переменные, а с самой большой корреляцыей по модулю

# %%
corr = df.corr(numeric_only=True)

plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# ## модель2- по макс абс корр

# %%
corr = df.corr(numeric_only=True)

target = "Government Budget Revenues"   # или любой другой столбец

top8 = corr[target].abs().sort_values(ascending=False).iloc[1:9]
top8
# Out:
# Gross National Savings                    0.921843
# Foreign Reserves                          0.861418
# Natural Gas Production                    0.780951
# Iron Ore Production                       0.767583
# OIL Production                            0.755381
# Date                                      0.726436
# Oil Prices                                0.723365
# Fuel Exports, % of Merchandise Exports    0.685470
# Name: Government Budget Revenues, dtype: float64

# %%
y = df["Government Budget Revenues"]   # целевая

X = df[[
    'Gross National Savings',
    'Foreign Reserves',
    'Natural Gas Production',
    'Iron Ore Production',
    'OIL Production',
    'Date',
    'Oil Prices',
    'Fuel Exports, % of Merchandise Exports'
]]

X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     Government Budget Revenues   R-squared:                       0.935
# Model:                                    OLS   Adj. R-squared:                  0.915
# Method:                         Least Squares   F-statistic:                     45.20
# Date:                        Sun, 30 Nov 2025   Prob (F-statistic):           5.71e-13
# Time:                                09:10:54   Log-Likelihood:                -335.49
# No. Observations:                          34   AIC:                             689.0
# Df Residuals:                              25   BIC:                             702.7
# Df Model:                                   8
# Covariance Type:                    nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# const                                  -1.039e+05   1.56e+06     -0.066      0.948   -3.32e+06    3.12e+06
# Gross National Savings                     0.2832      0.142      1.999      0.057      -0.009       0.575
# Foreign Reserves                           0.5647      0.190      2.967      0.007       0.173       0.957
# Natural Gas Production                   -86.1337    340.552     -0.253      0.802    -787.514     615.246
# Iron Ore Production                       -0.1577      0.118     -1.339      0.192      -0.400       0.085
# OIL Production                             3.6693     18.544      0.198      0.845     -34.524      41.862
# Date                                      41.2815    783.269      0.053      0.958   -1571.891    1654.454
# Oil Prices                               253.4991     67.974      3.729      0.001     113.504     393.494
# Fuel Exports, % of Merchandise Exports   210.7846    222.802      0.946      0.353    -248.084     669.653
# ==============================================================================
# Omnibus:                        9.807   Durbin-Watson:                   2.085
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):               10.894
# Skew:                          -0.781   Prob(JB):                      0.00431
# Kurtosis:                       5.291   Cond. No.                     9.67e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.67e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model.params.round(5)
# Out:
# const                                    -103944.07434
# Gross National Savings                         0.28322
# Foreign Reserves                               0.56467
# Natural Gas Production                       -86.13375
# Iron Ore Production                           -0.15771
# OIL Production                                 3.66927
# Date                                          41.28150
# Oil Prices                                   253.49911
# Fuel Exports, % of Merchandise Exports       210.78460
# dtype: float64

# %%
p = model.pvalues

significant = [var for var in p.index if p[var] < 0.10]
nonsignificant = [var for var in p.index if p[var] >= 0.10]

print("Значимые переменные:", significant)
print("Незначимые переменные:", nonsignificant)
# Out:
# Значимые переменные: ['Gross National Savings', 'Foreign Reserves', 'Oil Prices']
# Незначимые переменные: ['const', 'Natural Gas Production', 'Iron Ore Production', 'OIL Production', 'Date', 'Fuel Exports, % of Merchandise Exports']

# %% [markdown]
# также, построим 95% доверительные интервалы для всех коэффициентов:

# %%
conf = model.conf_int(alpha=0.05)

significant_ci = []
nonsignificant_ci = []

for var in conf.index:
    low, high = conf.loc[var]
    if low > 0 or high < 0:      # интервал не содержит ноль
        significant_ci.append(var)
    else:
        nonsignificant_ci.append(var)

print("Значимые по доверительным интервалам:", significant_ci)
print("Незначимые по доверительным интервалам:", nonsignificant_ci)
# Out:
# Значимые по доверительным интервалам: ['Foreign Reserves', 'Oil Prices']
# Незначимые по доверительным интервалам: ['const', 'Gross National Savings', 'Natural Gas Production', 'Iron Ore Production', 'OIL Production', 'Date', 'Fuel Exports, % of Merchandise Exports']

# %% [markdown]
# ### 11.  Проведите проверку результатов на устойчивость. Метод Вы выбираете сами. Устойчивы ли Ваши результаты?

# %% [markdown]
# #### 1 способ: Робастные стандартные ошибки (HC3)

# %%
model_robust = model.get_robustcov_results(cov_type="HC3")

p = model_robust.pvalues
names = model_robust.model.exog_names

significant = [names[i] for i in range(len(p)) if p[i] < 0.10]
nonsignificant = [names[i] for i in range(len(p)) if p[i] >= 0.10]

print("Значимые (robust):", significant)
print("Незначимые (robust):", nonsignificant)
# Out:
# Значимые (robust): ['Oil Prices']
# Незначимые (robust): ['const', 'Gross National Savings', 'Foreign Reserves', 'Natural Gas Production', 'Iron Ore Production', 'OIL Production', 'Date', 'Fuel Exports, % of Merchandise Exports']

# %% [markdown]
# #### 2 способ: Мультиколлинеарность (VIF)

# %%
vif_data = pd.DataFrame()
vif_data["Variable"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif_data.round(2)
# Out:
#                                  Variable         VIF
# 0                                   const  2805938.08
# 1                  Gross National Savings       10.92
# 2                        Foreign Reserves        7.49
# 3                  Natural Gas Production       16.09
# 4                     Iron Ore Production        4.84
# 5                          OIL Production      109.04
# 6                                    Date       67.76
# 7                              Oil Prices        2.87
# 8  Fuel Exports, % of Merchandise Exports        8.70

# %% [markdown]
# #### 3 способ: оценка модели на части признаков. (Leave-one-out robustness check)
#
# Мы проверяем, насколько чувствительны результаты модели к выбору набора регрессоров. Для этого по очереди исключаем из модели каждую объясняющую переменную, заново оцениваем регрессию и смотрим, как изменяется коэффициент при ключевой переменной FiscalRule. Если коэффициент остаётся примерно таким же, значит модель устойчива к спецификации; если изменяется резко, значит зависимость чувствительна к исключению этой переменной.
#
# Этот метод широко используется как тест устойчивости результатов (robustness to model specification).

# %%
y = df["Government Budget Revenues"]   # новая зависимая

control_vars = [
    'Gross National Savings',
    'Foreign Reserves',
    'Natural Gas Production',
    'Iron Ore Production',
    'OIL Production',
    'Date',
    'Fuel Exports, % of Merchandise Exports'
]

results = []

for var in control_vars:
    vars_subset = [v for v in control_vars if v != var]
    model = sm.OLS(y, sm.add_constant(df[vars_subset + ["Oil Prices"]])).fit()
    coef = model.params.get("Oil Prices", None)
    results.append([var, coef])

pd.DataFrame(results, columns=["Removed variable", "OilPrices coefficient"])
# Out:
#                          Removed variable  OilPrices coefficient
# 0                  Gross National Savings             347.785907
# 1                        Foreign Reserves             254.680054
# 2                  Natural Gas Production             258.898699
# 3                     Iron Ore Production             230.734718
# 4                          OIL Production             258.490601
# 5                                    Date             252.027564
# 6  Fuel Exports, % of Merchandise Exports             221.667650

# %% [markdown]
# ### 12.  Постройте прогноз, используя Вашу оцененную модель. Результаты представьте на графике. Опишите его и проинтерпретируйте.

# %% [markdown]
# прогноз по 3-летнему скользящему среднему (MA-3) и подстановка результата OLS-модель.

# %%
X_vars = [
    'Gross National Savings',
    'Foreign Reserves',
    'Natural Gas Production',
    'Iron Ore Production',
    'OIL Production',
    'Date',
    'Fuel Exports, % of Merchandise Exports',
    'Oil Prices'
]

future_years = [2026, 2027, 2028, 2029, 2030]

X_extended = df[X_vars].copy()

for year in future_years:
    ma3 = X_extended.tail(3).mean()
    X_extended.loc[year] = ma3

X_future = X_extended.loc[future_years].copy()
X_future["const"] = 1
X_future = X_future[model.model.exog_names]

forecast_ma = model.predict(X_future)

plt.figure(figsize=(10,5))
plt.plot(df["Date"], df["Government Budget Revenues"], label="Факт")
plt.plot(forecast_ma.index, forecast_ma.values, label="Прогноз (MA3)", linestyle="--")
plt.xlabel("Год")
plt.ylabel("Government Budget Revenues")
plt.legend()
plt.show()
